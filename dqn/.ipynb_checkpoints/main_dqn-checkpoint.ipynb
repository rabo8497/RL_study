# %%
import random, math
from itertools import count
from collections import deque, namedtuple
import matplotlib.pyplot as plt
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class Memory :
    def __init__(self, capacity=10000) :
        self.memory = deque([], maxlen=capacity)
    def push(self, trans) :
        self.memory.append(trans)
    def sample(self, num) :
        return random.sample(self.memory, num)
    def __len__(self) :
        return len(self.memory)

# %%
class Q_net(nn.Module) :
    def __init__(self, n_observations, n_actions) :
        super(Q_net, self).__init__()
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)
    def forward(self, x) :
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)

# %%
class Agent :
    def __init__(self, device, Transition, BATCH=128, GAMMA=0.99, TAU=0.005, LR=1e-4,
                EPS_START=0.9, EPS_END=0.05, EPS_DECAY=1000, capacity=100000) :
        self.device = device
        self.Transition = Transition
        self.BATCH = BATCH
        self.GAMMA = GAMMA
        self.TAU = TAU
        self.LR = LR
        self.EPS_START = EPS_START
        self.EPS_END = EPS_END
        self.EPS_DECAY = EPS_DECAY
        self.memory = Memory(capacity)
        self.n_observations = 4
        self.n_actions = 2
        self.time_step = 0
        self.policy_net = Q_net(self.n_observations, self.n_actions).to(device)
        self.policy_net.apply(self.init_weights)
        self.target_net = Q_net(self.n_observations, self.n_actions).to(device)
        self.target_net.load_state_dict(self.policy_net.state_dict())
        self.optimizer = optim.AdamW(self.policy_net.parameters(), lr=LR, amsgrad=True)
    def init_weights(self, m):
        if type(m) == nn.Linear:
            torch.nn.init.xavier_normal_(m.weight)
            m.bias.data.fill_(0)
    def select_action(self, state) :
        self.time_step += 1
        sample = random.random()
        eps_threshold = self.EPS_END + (self.EPS_START - self.EPS_END) * math.exp(-1 * self.time_step / self.EPS_DECAY)
        if sample > eps_threshold :
            with torch.no_grad() :
                return self.policy_net(state).max(1)[1].view(1, 1)
        else :
            return torch.tensor([[env.action_space.sample()]], device=self.device, dtype=torch.long)
    def optimize(self) :
        if len(self.memory) < self.BATCH :
            return
        transitions = self.memory.sample(self.BATCH)
        batch = self.Transition(*zip(*transitions))
        non_final_mask = torch.tensor(tuple(map(lambda s: s is not None, batch.next_state)), device=self.device, dtype=torch.bool)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        state_action_values = self.policy_net(state_batch).gather(1, action_batch)
        next_state_values = torch.zeros(self.BATCH, device=self.device)
        with torch.no_grad() :
            next_state_values[non_final_mask] = self.target_net(non_final_next_states).max(1)[0]
        expected_state_action_values = (next_state_values * self.GAMMA) + reward_batch
        criterion = nn.SmoothL1Loss()
        loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))
        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_value_(self.policy_net.parameters(), 100)
        self.optimizer.step()
    def update(self) :
        target_net_state_dict = self.target_net.state_dict()
        policy_net_state_dict = self.policy_net.state_dict()
        for key in policy_net_state_dict:
            target_net_state_dict[key] = policy_net_state_dict[key]*self.TAU + target_net_state_dict[key]*(1-self.TAU)
        self.target_net.load_state_dict(target_net_state_dict)

# %%
def main() :
    env = gym.make('CartPole-v1')
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    save_path = "main_dqn_model.pt"
    Transition = namedtuple('Transition', 
                           ('state', 'action', 'next_state', 'reward'))
    dqn_agent = Agent(device, Transition)
    
    num_episode = 1000
    scores = []

    for i_episode in range(num_episode) :
        if scores[-3:] == [500, 500, 500] :
            torch.save(dqn_agent.policy_net, save_path)
            print("달성, 저장 완료 (" + save_path + ")")
            env.close()
            plt.plot(scores)
            plt.title('episode-score graph')
            plt.xlabel('episode')
            plt.ylabel('score')
            plt.savefig('main_dqn.png')
            plt.show()
            return scores

        state = env.reset()
        state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
        i_episode_score = 0
        for t in count() :
            i_episode_score += 1
            action = dqn_agent.select_action(state)
            observation, reward, terminated, _ = env.step(action.item())
            reward = torch.tensor([reward], device=device)
            done = terminated
            if terminated:
                next_state = None
            else:
                next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)
            dqn_agent.memory.push(Transition(state, action, next_state, reward))
            state = next_state
            dqn_agent.optimize()
            dqn_agent.update()
            
            if done :
                print(str(i_episode+1) + "번째 episode : " + str(i_episode_score))
                scores.append(i_episode_score)
                break
    
    print("저장 완료 (" + save_path + ")")
    env.close()
    plt.plot(scores)
    plt.title('episode-score graph')
    plt.xlabel('episode')
    plt.ylabel('score')
    plt.savefig('main_dqn.png')
    plt.show()
    return scores

# %%
if __name__ == "__main__" :
    main()
# Out:
# 1번째 episode : 42
# 2번째 episode : 14
# 3번째 episode : 15
# 4번째 episode : 13
# 5번째 episode : 16
# 6번째 episode : 16
# 7번째 episode : 14
# 8번째 episode : 22
# 9번째 episode : 15
# 10번째 episode : 13
# 11번째 episode : 72
# 12번째 episode : 9
# 13번째 episode : 12
# 14번째 episode : 17
# 15번째 episode : 11
# 16번째 episode : 11
# 17번째 episode : 14
# 18번째 episode : 9
# 19번째 episode : 28
# 20번째 episode : 13
# 21번째 episode : 13
# 22번째 episode : 28
# 23번째 episode : 11
# 24번째 episode : 9
# 25번째 episode : 15
# 26번째 episode : 13
# 27번째 episode : 15
# 28번째 episode : 10
# 29번째 episode : 10
# 30번째 episode : 10
# 31번째 episode : 14
# 32번째 episode : 10
# 33번째 episode : 12
# 34번째 episode : 20
# 35번째 episode : 13
# 36번째 episode : 18
# 37번째 episode : 13
# 38번째 episode : 16
# 39번째 episode : 11
# 40번째 episode : 9
# 41번째 episode : 13
# 42번째 episode : 9
# 43번째 episode : 12
# 44번째 episode : 9
# 45번째 episode : 14
# 46번째 episode : 11
# 47번째 episode : 13
# 48번째 episode : 9
# 49번째 episode : 9
# 50번째 episode : 11
# 51번째 episode : 11
# 52번째 episode : 16
# 53번째 episode : 9
# 54번째 episode : 10
# 55번째 episode : 10
# 56번째 episode : 12
# 57번째 episode : 14
# 58번째 episode : 14
# 59번째 episode : 9
# 60번째 episode : 9
# 61번째 episode : 10
# 62번째 episode : 11
# 63번째 episode : 9
# 64번째 episode : 10
# 65번째 episode : 16
# 66번째 episode : 9
# 67번째 episode : 8
# 68번째 episode : 11
# 69번째 episode : 10
# 70번째 episode : 12
# 71번째 episode : 10
# 72번째 episode : 10
# 73번째 episode : 13
# 74번째 episode : 9
# 75번째 episode : 11
# 76번째 episode : 14
# 77번째 episode : 11
# 78번째 episode : 11
# 79번째 episode : 8
# 80번째 episode : 10
# 81번째 episode : 12
# 82번째 episode : 17
# 83번째 episode : 16
# 84번째 episode : 10
# 85번째 episode : 10
# 86번째 episode : 14
# 87번째 episode : 10
# 88번째 episode : 10
# 89번째 episode : 13
# 90번째 episode : 10
# 464번째 episode : 333
# 465번째 episode : 278
# 466번째 episode : 172
# 467번째 episode : 293
# 468번째 episode : 289
# 469번째 episode : 273
# 470번째 episode : 289
# 471번째 episode : 174
# 472번째 episode : 257
# 473번째 episode : 295
# 474번째 episode : 307
# 475번째 episode : 285
# 476번째 episode : 358
# 477번째 episode : 216
# 478번째 episode : 245
# 479번째 episode : 220
# 480번째 episode : 267
# 481번째 episode : 238
# 482번째 episode : 131
# 483번째 episode : 248
# 484번째 episode : 279
# 485번째 episode : 292
# 486번째 episode : 304
# 487번째 episode : 264
# 488번째 episode : 218
# 489번째 episode : 251
# 490번째 episode : 225
# 491번째 episode : 238
# 492번째 episode : 260
# 493번째 episode : 238
# 494번째 episode : 236
# 495번째 episode : 264
# 496번째 episode : 245
# 497번째 episode : 264
# 498번째 episode : 200
# 499번째 episode : 252
# 500번째 episode : 221
# 501번째 episode : 219
# 502번째 episode : 225
# 503번째 episode : 233
# 504번째 episode : 223
# 505번째 episode : 216
# 506번째 episode : 222
# 507번째 episode : 220
# 508번째 episode : 214
# 509번째 episode : 200
# 510번째 episode : 251
# 511번째 episode : 225
# 512번째 episode : 237
# 513번째 episode : 241
# 514번째 episode : 271
# 515번째 episode : 247
# 516번째 episode : 281
# 517번째 episode : 266
# 518번째 episode : 312
# 519번째 episode : 500
# 520번째 episode : 500
# 521번째 episode : 500
# 달성, 저장 완료 (main_dqn_model.pt)

# %%
import time

def test_model(path) :
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    n_observations = 4
    n_actions = 2
    model = Q_net(n_observations, n_actions).to(device)
    model.load_state_dict(torch.load(path))
    env = gym.make('CartPole-v1', render_mode = 'human')
    state = env.reset()
    done = False
    score = 0
    while not done :
        env.render()
        state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
        time.sleep(0.1)
        action = model(state).max(1)[1].view(1, 1)
        state, reward, done, _ = env.step(action.item())
        score += reward

# %%
test_model("main_dqn_model.pt")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 test_model("main_dqn_model.pt")
#
# Cell In[86], line 8, in test_model(path)
#       6 n_actions = 2
#       7 model = Q_net(n_observations, n_actions).to(device)
# ----> 8 model.load_state_dict(torch.load(path, map_location="cpu"))
#       9 env = gym.make('CartPole-v1', render_mode = 'human')
#      10 state = env.reset()
#
# File D:\Anaconda\envs\torch\lib\site-packages\torch\nn\modules\module.py:1624, in Module.load_state_dict(self, state_dict, strict)
#    1601 r"""Copies parameters and buffers from :attr:`state_dict` into
#    1602 this module and its descendants. If :attr:`strict` is ``True``, then
#    1603 the keys of :attr:`state_dict` must exactly match the keys returned
#    (...)
#    1621     ``RuntimeError``.
#    1622 """
#    1623 if not isinstance(state_dict, Mapping):
# -> 1624     raise TypeError("Expected state_dict to be dict-like, got {}.".format(type(state_dict)))
#    1626 missing_keys: List[str] = []
#    1627 unexpected_keys: List[str] = []
#
# TypeError: Expected state_dict to be dict-like, got <class '__main__.Q_net'>.

# %%
torch.load("main_dqn_model.pt")['weight']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 torch.load("main_dqn_model.pt")['weight']
#
# TypeError: 'Q_net' object is not subscriptable
